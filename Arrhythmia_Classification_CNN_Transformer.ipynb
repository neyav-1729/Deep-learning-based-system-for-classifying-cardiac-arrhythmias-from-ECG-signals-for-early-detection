# %% [markdown]
# <a href="https://colab.research.google.com/github/neyav-1729/Deep-learning-based-system-for-classifying-cardiac-arrhythmias-from-ECG-signals-for-early-detection/blob/main/Arrhythmia_Classification_CNN_Transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install numpy scipy scikit-learn imbalanced-learn wfdb

# %%
# =========================
# Install dependencies
# =========================
# !pip install wfdb

# =========================
# Imports
# =========================
import wfdb
import numpy as np
from scipy.signal import butter, lfilter
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
from collections import Counter

import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# =========================
# Custom Focal Loss (works on ANY TensorFlow version)
# =========================
def focal_loss(gamma=2., alpha=0.25):
    def loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1.0)

        ce = -y_true * tf.math.log(y_pred)
        weight = alpha * tf.math.pow((1 - y_pred), gamma)
        fl = weight * ce
        return tf.reduce_sum(fl, axis=1)
    return loss

# =========================
# AAMI 5-Class Mapping
# =========================
def map_to_aami(label):
    if label in ['N','L','R','e','j']: return 'N'
    elif label in ['A','a','J','S']: return 'S'
    elif label in ['V','E']: return 'V'
    elif label == 'F': return 'F'
    elif label in ['/', 'f', 'Q']: return 'Q'
    else: return None

# =========================
# ECG Preprocessing + RR Intervals
# =========================
def load_and_preprocess_single_record(record_number):
    record = wfdb.rdrecord(record_number, pn_dir='mitdb/')
    annotation = wfdb.rdann(record_number, 'atr', pn_dir='mitdb/')

    signal = record.p_signal[:,0]
    fs = record.fs
    r_peaks = annotation.sample

    # Bandpass filter
    low, high = 0.5, 40
    nyq = 0.5 * fs
    b, a = butter(4, [low/nyq, high/nyq], btype='band')
    filtered = lfilter(b, a, signal)

    # Normalize
    scaler = MinMaxScaler()
    norm_signal = scaler.fit_transform(filtered.reshape(-1,1)).flatten()

    # Output arrays
    segments, labels, rr_features = [], [], []

    pre = int(0.2 * fs)
    post = int(0.3 * fs)

    for i in range(1, len(r_peaks)-1):
        start = r_peaks[i] - pre
        end   = r_peaks[i] + post

        if start < 0 or end >= len(norm_signal):
            continue

        aami = map_to_aami(annotation.symbol[i])
        if aami is None:
            continue

        rr_prev = (r_peaks[i] - r_peaks[i-1]) / fs
        rr_next = (r_peaks[i+1] - r_peaks[i]) / fs

        rr_features.append([rr_prev, rr_next])
        segments.append(norm_signal[start:end])
        labels.append(aami)

    return np.array(segments), np.array(rr_features), np.array(labels)

# =========================
# Load MIT-BIH records
# =========================
record_numbers = [
 '100','101','102','103','104','105','106','107','108','109','111','112',
 '113','114','115','116','117','118','119','121','122','123','124','200',
 '201','202','203','205','207','208','209','210','212','213','214','215',
 '217','219','220','221','222','223','228','230','231','232','233','234'
]

all_X, all_RR, all_y = [], [], []

for rec in record_numbers:
    X, RR, y = load_and_preprocess_single_record(rec)
    all_X.append(X)
    all_RR.append(RR)
    all_y.append(y)

X = np.concatenate(all_X)
RR = np.concatenate(all_RR)
y = np.concatenate(all_y)

print("Total beats:", len(y))
print("Class distribution:", Counter(y))

# =========================
# Label encoding
# =========================
labels = np.unique(y)
label_to_int = {lbl:i for i,lbl in enumerate(labels)}
int_to_label = {i:lbl for lbl,i in label_to_int.items()}

y_int = np.array([label_to_int[l] for l in y])

# =========================
# Split
# =========================
X_train, X_test, RR_train, RR_test, y_train, y_test = train_test_split(
    X, RR, y_int, test_size=0.2, stratify=y_int, random_state=42
)

X_train = np.expand_dims(X_train, -1)
X_test  = np.expand_dims(X_test, -1)

num_classes = len(labels)
y_train_cat = tf.keras.utils.to_categorical(y_train, num_classes)
y_test_cat  = tf.keras.utils.to_categorical(y_test, num_classes)

# =========================
# Transformer block
# =========================
def transformer_block(x, heads=4, ff_dim=128):
    attn = MultiHeadAttention(num_heads=heads, key_dim=x.shape[-1])(x, x)
    x = LayerNormalization()(x + attn)

    f = Dense(ff_dim, activation="relu")(x)
    f = Dense(x.shape[-1])(f)
    return LayerNormalization()(x + f)

# =========================
# Build Two-Input Model
# =========================
ecg_in = Input(shape=(X_train.shape[1],1))
rr_in  = Input(shape=(2,))

# CNN for ECG
x = Conv1D(32,7,padding="same",activation="relu")(ecg_in)
x = MaxPooling1D(2)(x)
x = Conv1D(64,5,padding="same",activation="relu")(x)
x = MaxPooling1D(2)(x)
x = transformer_block(x)
x = GlobalAveragePooling1D()(x)

# RR branch
rr_branch = Dense(16, activation="relu")(rr_in)

# Merge
merged = Concatenate()([x, rr_branch])
merged = Dense(128, activation="relu")(merged)
merged = Dropout(0.3)(merged)

output = Dense(num_classes, activation="softmax")(merged)

model = Model([ecg_in, rr_in], output)
model.compile(optimizer=Adam(0.001), loss=focal_loss(), metrics=["accuracy"])
model.summary()

# =========================
# Training
# =========================
callbacks = [
    EarlyStopping(patience=5, restore_best_weights=True),
    ReduceLROnPlateau(patience=2, factor=0.5),
    ModelCheckpoint("best_rr_focal.keras", save_best_only=True)
]

history = model.fit(
    [X_train, RR_train], y_train_cat,
    validation_split=0.15,
    epochs=40,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)

# =========================
# Evaluation
# =========================
model = tf.keras.models.load_model("best_rr_focal.keras", compile=False)
model.compile(optimizer=Adam(0.001), loss=focal_loss(), metrics=["accuracy"])

loss, acc = model.evaluate([X_test, RR_test], y_test_cat)
print("\nTest Accuracy:", acc)

y_pred = np.argmax(model.predict([X_test, RR_test]), axis=1)

print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=labels))

# =========================
# Confusion Matrix
# =========================
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(7,5))
plt.imshow(cm, cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.colorbar()
plt.show()

# =========================
# Training Curves
# =========================
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Accuracy")

plt.subplot(1,2,2)
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Loss")
plt.show()
# Out:
# ...
# Total beats: 109438
# Class distribution: Counter({np.str_('N'): 90583, np.str_('Q'): 8039, np.str_('V'): 7235, np.str_('S'): 2779, np.str_('F'): 802})
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 180, 1)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 180, 32)   │        256 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 90, 32)    │          0 │ conv1d[0][0]      │
# │ (MaxPooling1D)      │                   │            │                   │
# ...

# %%
# Save the model (architecture + weights + optimizer state)
model.save("cardiac_arrhythmia_cnn_transformer_model.h5")

print("✅ Model saved successfully as cardiac_arrhythmia_cnn_transformer_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Model saved successfully as cardiac_arrhythmia_cnn_transformer_model.h5
